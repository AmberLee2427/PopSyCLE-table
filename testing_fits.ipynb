# %% [markdown]
# # What's going on with the fits?

# %%
import numpy as np
import pandas as pd

# %%
params = pd.read_csv("output-3.csv")

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
params.head()
# Out:
#       F_best  F_best_Spitzer      best1_u0  best1_t0  best1_tE    best1_fs  \
# 0  43.311407      309.707988  3.310254e-07 -0.083435  0.278324  151.942181
# 1  42.676270      309.736141  2.595789e+00  0.031300  0.316146  833.349539
#
#      best1_fb  best2_u0   best2_t0  best2_tE   best2_fs   best2_fb  \
# 0 -108.985040 -0.280841 -74.613074  0.024156  32.619580  10.630747
# 1 -790.816304 -0.000281 -70.656450  2.363656   0.298208  42.220329
#
#    best1Spitzer_u0  best1Spitzer_t0  best1Spitzer_tE  best1Spitzer_fs  \
# 0         0.461969     4.449713e+15         0.843605       247.037601
# 1         0.461280     2.916512e+15         0.834760       247.050899
#
#    best1Spitzer_fb  best2Spitzer_u0  best2Spitzer_t0  best2Spitzer_tE  \
# 0        62.670388         0.462143     4.449713e+15         0.843605
# 1        62.685243         0.461455     2.916512e+15         0.834760
#
#    best2Spitzer_fs  best2Spitzer_fb  chi2_earth_flat  chi2_earth_binary  \
# ...
